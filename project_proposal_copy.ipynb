# %%
import pandas as pd
import numpy as np

import altair as alt

# Save a vega-lite spec and a PNG blob for each plot in the notebook
alt.renderers.enable('mimetype')
# Handle large data sets without embedding them in the notebook
alt.data_transformers.enable('data_server')

# Load the R cell magic
# %load_ext rpy2.ipython

# %% [markdown]
# # Topic: Housing Prices

# %% [markdown]
# ### Dataset: Melbourne Housing Market
#
# link: https://www.kaggle.com/anthonypino/melbourne-housing-market
#
# description:
# The data comes from publicly available results posted every week from Domain.com.au. The dataset includes Address, Type of Real estate, Suburb, Method of Selling, Rooms, Price, Real Estate Agent, Date of Sale and distance from C.B.D. of the city of Melbourne.
#
# Potential research questions:
#
# 1. Given postcode or housing type, what is the average housing price, number of bedrooms and bathrooms, distance from CBD for that region and postcode?
#
# 1. What are the important features that contribute to the housing sale price in Melbourne given postcide and housing type?
#
# 2. Can we predict housing sale prices based on features of this dataset?

# %%
housing_price = pd.read_csv("Melbourne_housing_FULL.csv")

# %%
housing_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         34857 non-null  object
#  6   SellerG        34857 non-null  object
#  7   Date           34857 non-null  object
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  BuildingArea   13742 non-null  float64
#  15  YearBuilt      15551 non-null  float64
#  16  CouncilArea    34854 non-null  object
# ...

# %% [markdown]
# ### Dashboard Sketch

# %%
from IPython.display import Image
Image(filename='sketch.jpg')
